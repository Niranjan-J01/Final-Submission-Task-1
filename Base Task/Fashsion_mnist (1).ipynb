# %%
# !python fashsion_mnist.py
# Out:
# S.NO:1 epoch_trainloss  = 0.7197037797570228 $ epoch_val_loss = 0.5037449620505596
# S.NO:2 epoch_trainloss  = 0.44941774638493853 $ epoch_val_loss = 0.44350139313238734
# S.NO:3 epoch_trainloss  = 0.4154876435200373 $ epoch_val_loss = 0.4232543769510502
# S.NO:4 epoch_trainloss  = 0.3929918745160103 $ epoch_val_loss = 0.3985547535121441
# S.NO:5 epoch_trainloss  = 0.38043431772788366 $ epoch_val_loss = 0.4027810808508954
# S.NO:6 epoch_trainloss  = 0.3695992184281349 $ epoch_val_loss = 0.39099374421416444
# S.NO:7 epoch_trainloss  = 0.36156785623232524 $ epoch_val_loss = 0.39496769470737336
# S.NO:8 epoch_trainloss  = 0.3516993349790573 $ epoch_val_loss = 0.3782765979462482
# S.NO:9 epoch_trainloss  = 0.3464290638566017 $ epoch_val_loss = 0.4114546935926092
# S.NO:10 epoch_trainloss  = 0.3391844508051872 $ epoch_val_loss = 0.3902346154952303
# S.NO:11 epoch_trainloss  = 0.33384291527668636 $ epoch_val_loss = 0.3667871344913828
# ...

# %% [markdown]
# ![image.png](attachment:image.png)
